# %%
import main

main.main()
# Out:
# value of i is 1
# Playing with both players with random strategies
# Player 1 Wins: 100%
# Player 2 Wins: 0%
# Draws: 0.0%
# Draws: 0
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 1.0697 - accuracy: 0.4286 - val_loss: 1.0356 - val_accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0397 - accuracy: 0.5714 - val_loss: 0.9998 - val_accuracy: 0.7500
# Epoch 3/100
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0087 - accuracy: 1.0000 - val_loss: 0.9681 - val_accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9903 - accuracy: 1.0000 - val_loss: 0.9372 - val_accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9785 - accuracy: 1.0000 - val_loss: 0.9029 - val_accuracy: 1.0000
# Epoch 6/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9542 - accuracy: 1.0000 - val_loss: 0.8659 - val_accuracy: 1.0000
# ...

# %%
x, y = main.main()
# Out:
# value of i is 1
# Playing with both players with random strategies
# Player 1 Wins: 100%
# Player 2 Wins: 0%
# Draws: 0.0%
# Draws: 0
# Epoch 1/100
# 1/1 [==============================] - 1s 953ms/step - loss: 0.9935 - accuracy: 0.8824 - val_loss: 0.7774 - val_accuracy: 1.0000
# Epoch 2/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9216 - accuracy: 1.0000 - val_loss: 0.7171 - val_accuracy: 1.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8863 - accuracy: 1.0000 - val_loss: 0.6624 - val_accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8292 - accuracy: 1.0000 - val_loss: 0.6066 - val_accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8129 - accuracy: 1.0000 - val_loss: 0.5505 - val_accuracy: 1.0000
# Epoch 6/100
# ...

# %%
print(y)
# Out:
# [100, 0, 100, 0, 100, 0, 100, 0, 0, 0]
