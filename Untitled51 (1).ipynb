# %%
import main
main.main()
# Out:
# Player 1 Wins: 56%
# Player 2 Wins: 43%
# Draws: 0.27586206896551724%
# Draws: 40
# Player 1 Wins: 55%
# Player 2 Wins: 44%
# Draws: 0.3%
# Draws: 39
# Epoch 1/100
# 4334/4334 [==============================] - 7s 1ms/step - loss: 0.7042 - accuracy: 0.5872 - val_loss: 0.7099 - val_accuracy: 0.5849
# Epoch 2/100
# 4334/4334 [==============================] - 6s 1ms/step - loss: 0.6529 - accuracy: 0.6262 - val_loss: 0.7304 - val_accuracy: 0.5811
# Epoch 3/100
# 4334/4334 [==============================] - 7s 2ms/step - loss: 0.6342 - accuracy: 0.6396 - val_loss: 0.7404 - val_accuracy: 0.5791
# Epoch 4/100
# 4334/4334 [==============================] - 7s 2ms/step - loss: 0.6207 - accuracy: 0.6516 - val_loss: 0.7506 - val_accuracy: 0.5764
# Epoch 5/100
# 4334/4334 [==============================] - 7s 2ms/step - loss: 0.6134 - accuracy: 0.6573 - val_loss: 0.7558 - val_accuracy: 0.5768
# Epoch 6/100
# ...

# %%
import main
main.main()
# Out:
# Player 1 Wins: 55%
# Player 2 Wins: 44%
# Draws: 0.2620689655172414%
# Draws: 38
# Player 1 Wins: 55%
# Player 2 Wins: 44%
# Draws: 0.17692307692307693%
# Draws: 23
# Epoch 1/100
# 4345/4345 [==============================] - 6s 1ms/step - loss: 0.7128 - accuracy: 0.5757 - val_loss: 0.6978 - val_accuracy: 0.5902
# Epoch 2/100
# 4345/4345 [==============================] - 5s 1ms/step - loss: 0.6554 - accuracy: 0.6214 - val_loss: 0.7188 - val_accuracy: 0.5850
# Epoch 3/100
# 4345/4345 [==============================] - 5s 1ms/step - loss: 0.6359 - accuracy: 0.6375 - val_loss: 0.7231 - val_accuracy: 0.5836
# Epoch 4/100
# 4345/4345 [==============================] - 5s 1ms/step - loss: 0.6200 - accuracy: 0.6507 - val_loss: 0.7445 - val_accuracy: 0.5888
# Epoch 5/100
# 4345/4345 [==============================] - 5s 1ms/step - loss: 0.6125 - accuracy: 0.6553 - val_loss: 0.7465 - val_accuracy: 0.5825
# Epoch 6/100
# ...
