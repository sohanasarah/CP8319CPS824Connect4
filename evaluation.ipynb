# %%
import main

# %%
res = main.main()
# Out:
# Creating Players
# Creating Training Data
# Player 1 Wins: 55.46896551724138%
# Player 2 Wins: 44.255172413793105%
# Draws: 0.27586206896551724%
# Player 1 Wins: 55.66923076923077%
# Player 2 Wins: 44.06153846153846%
# Draws: 0.2692307692307692%
# Epoch 1/100
# 4341/4341 [==============================] - 6s 1ms/step - loss: 0.7120 - accuracy: 0.5736 - val_loss: 0.7313 - val_accuracy: 0.5683
# Epoch 2/100
# 4341/4341 [==============================] - 5s 1ms/step - loss: 0.6669 - accuracy: 0.6094 - val_loss: 0.7371 - val_accuracy: 0.5743
# Epoch 3/100
# 4341/4341 [==============================] - 4s 1ms/step - loss: 0.6514 - accuracy: 0.6259 - val_loss: 0.7444 - val_accuracy: 0.5713
# Epoch 4/100
# 4341/4341 [==============================] - 4s 1ms/step - loss: 0.6426 - accuracy: 0.6312 - val_loss: 0.7489 - val_accuracy: 0.5752
# Epoch 5/100
# 4341/4341 [==============================] - 5s 1ms/step - loss: 0.6353 - accuracy: 0.6391 - val_loss: 0.7486 - val_accuracy: 0.5736
# ...
