# %%
import gym
import main
x,y = main.main()
# Out:
# value is 1
# Playing with both players with random strategies
# Player 1 Wins: 0%
# Player 2 Wins: 100%
# Draws: 0.0%
# Draws: 0
# (9, 1, 42)
# Epoch 1/100
# 1/1 [==============================] - 0s 349ms/step - loss: 1.0642 - accuracy: 1.0000 - val_loss: 0.9926 - val_accuracy: 1.0000
# Epoch 2/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0472 - accuracy: 1.0000 - val_loss: 0.9781 - val_accuracy: 1.0000
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0340 - accuracy: 1.0000 - val_loss: 0.9638 - val_accuracy: 1.0000
# Epoch 4/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0233 - accuracy: 1.0000 - val_loss: 0.9506 - val_accuracy: 1.0000
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0092 - accuracy: 1.0000 - val_loss: 0.9356 - val_accuracy: 1.0000
# Epoch 6/100
# ...
